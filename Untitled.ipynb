# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('new_dataset.csv')
data.head()
# Out:
#              track_id    duration  end_of_fade_in  key_confidence  loudness  \
# 0  TRDJCZP12903CE7498   268.38159           0.000           0.625    -8.629
# 1  TRDJCUX128F425F866   236.14649           0.257           0.425   -14.287
# 2  TRDJCCR12903CAFA73  1517.60934          13.857           0.129   -17.578
# 3  TRDJCNE128F428BE28   171.15383           0.229           0.632    -7.108
# 4  TRDJCET128F9312133   222.85016           0.409           0.838   -19.036
#
#    mode_confidence  start_of_fade_out    tempo  time_signature_confidence  \
# 0            0.559            257.231   82.811                      0.561
# 1            0.469            212.764  139.583                      0.228
# 2            0.228           1504.496  119.700                      1.000
# 3            0.517            164.577  202.356                      0.413
# 4            0.620            215.673   89.553                      0.555
#
# ...

# %%
data.boxplot(column = ['mode_1', 'tempo'])
